# %% [markdown]
# # Practice question on function

# %% [markdown]
# ### 1. Difference Between print and return

# %% [raw]
#  1)Write a function sum_numbers(a, b) that takes two numbers as input and does the following:

# %% [raw]
#  a.Prints the sum of the numbers.

# %%
def sum_numbers(a,b):
     print(a+b)

# %%
sum_numbers(3,6)
# Out:
# 9

# %% [raw]
#  b.Returns the sum of the numbers.

# %%
def sum_numbers(a, b):
    total = a + b
    return total

# %%
sum_numbers(9,4)
# Out:
# 13

# %% [raw]
# c.Call the function and explain the difference between the print and return values.

# %%
def sum_numbers(a,b):
    print(a+b)
def sum_numbers(a,b):
    total = a+b
    return total

# %%
print(sum_numbers(2,6))
# Out:
# 8

# %%
sum_numbers(5,6)
# Out:
# 11

# %%
type(print(sum_numbers(2,6)))
# Out:
# 8
# NoneType

# %%
type(sum_numbers(5,6))
# Out:
# int

# %%
# in print it doesnt give actual value also it didn't give proper datatypes and can be execute multiple time whereas return give actual value and give correct datatype and it only execute one time

# %% [markdown]
# #### 2.Local and Global Variables

# %% [raw]
# 1) Write a program where:
#  - You define a global variable counter with an initial value of 0.
#  - Create a function increment() that increments counter by 1 each time it is called and prints its value.
#  - Call the function three times and observe the output.

# %%
counter = 0
def increment():
    global counter
    counter += 1
    print(counter)

# %%
increment()
increment()
increment()
# Out:
# 1
# 2
# 3

# %% [raw]
# 2) Write a function demo_local() that declares a local variable message = "Hello, Local" and prints it.
# Outside the function, try to print the same message variable and note the error.

# %%
def demo_local():
    message = "Hello, Local"
    print(message)

# %%
demo_local()
# Out:
# Hello, Local

# %%
def demo_local():
    message = "Hello, Local"
    print(message)
    
demo_local()

print(message)
# Out:
# Hello, Local
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 7
#       3     print(message)
#       5 demo_local()
# ----> 7 print(message)
#
# NameError: name 'message' is not defined

# %% [raw]
# 3)Modify demo_local() from the previous question to access a global variable message = "Hello, Global" from within the function.

# %%
message = "Hello, Global"

def demo_global():
    print(message)

# %%
demo_global()
# Out:
# Hello, Global

# %% [markdown]
# #### 3.Writing Docstrings

# %% [raw]
# 1)Write a function calculate_area(radius) to compute the area of a circle given its radius.
# - Add a docstring explaining the formula used for calculation and the purpose of the function.

# %%
def calculate_area(radius):
    """ this is the formula for calculating area of circle
    = 3.14*r*r"""
    print(3.14*radius*radius)

# %%
calculate_area(5)
# Out:
# 78.5

# %% [raw]
# 2) Write a function is_even(n) that returns True if a number is even, otherwise returns False. Test the function with multiple inputs.

# %%
def is_even(n):
    if n % 2 == 0:
        return True
    else:
        return False

# %%
is_even(2)
# Out:
# True

# %%
is_even(9)
# Out:
# False
