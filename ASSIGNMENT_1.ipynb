# %% [markdown]
# ASSIGNMENT 1: PYTHON BASICS AND DATATYPES

# %% [markdown]
# 1. Variable Manipuation

# %% [raw]
# a)Define variables to store a student's name, age, GPA, and list of subjects.

# %%
first_name = "Ram"

# %%
age = 22

# %%
GPA = 7.5

# %%
Subject = ["Python , Math , Java "]

# %%
first_name
# Out:
# 'Ram'

# %%
age
# Out:
# 22

# %%
GPA
# Out:
# 7.5

# %%
Subject
# Out:
# ['Python , Math , Java ']

# %% [raw]
# b)Convert age from years to months and display the result.

# %%
age = 22

# %%
age_in_month = age*12

# %%
age_in_month
# Out:
# 264

# %% [raw]
# c)Concatenate and print a sentence using all the defined variables.

# %%
age = str(age)

# %%
type(age)
# Out:
# str

# %%
type(GPA)
# Out:
# float

# %%
GPA = str(GPA)

# %%
type(GPA)
# Out:
# str

# %%
age_in_month = str(age_in_month)

# %%
type(age_in_month)
# Out:
# str

# %%
sentence = "My first name is " + first_name + ", my age is " + age + ", my GPA is " + GPA + ", and my age in months is " + age_in_month + "."

# %%
print(sentence)
# Out:
# My first name is Ram, my age is 22, my GPA is 7.5, and my age in months is 264.

# %% [markdown]
# 2.Type Conversion Practice

# %% [raw]
# a) Convert a float to an integer, and explain what happens to the decimal part.

# %%
num = 12.34

# %%
num = int(num)

# %%
type(num)
# Out:
# int

# %%
num
# Out:
# 12

# %% [raw]
# Here if we convert an float number to an integer then it remove the number after the decimal point and only give integer number
