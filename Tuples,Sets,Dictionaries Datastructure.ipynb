# %% [markdown]
# # Tuple Datastructure

# %% [markdown]
#  ### 1.Immutability

# %% [raw]
# Given t = (1, 2, 3), what happens if you run t[1] = 20?

# %%
t = (1,2,3)

# %%
t[1] = 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 t[1] = 20
#
# TypeError: 'tuple' object does not support item assignment

# %%
# here t cannot be change as tuple is immutable it doesn't allow to change the value

# %% [markdown]
# ### 2.Counting

# %% [raw]
# If y = (1, 1, 2, 3, 1), what is the output of y.count(1)?

# %%
y = (1, 1, 2, 3, 1)

# %%
y.count(1)
# Out:
# 3

# %% [markdown]
# ### 3.Indexing

# %% [raw]
# How do you find the position of the value 7 in the tuple y = (10, 20, 7, 40)?

# %%
y = (10, 20, 7, 40)

# %%
y.index(7)
# Out:
# 2

# %% [markdown]
# ### 4.Nested Tuples

# %% [raw]
#  Given u = (10, 20, (50, 60), 90), write the code to access the number 60.

# %%
u = (10, 20, (50, 60), 90)

# %%
u[2][1]
# Out:
# 60

# %% [markdown]
# # Sets Datastructure

# %% [markdown]
# ### 1.Duplicate Removal

# %% [raw]
# What is the result of set([1, 2, 2, 3, 4, 4, 4])?

# %%
s = {1, 2, 2, 3, 4, 4, 4}

# %%
s
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# ### 2.Adding items

# %% [raw]
# How do you add the number 100 to a set named s?

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
s.add(100)

# %%
s
# Out:
# {1, 2, 3, 4, 100}

# %% [markdown]
# ### 3.Removing Items

# %% [raw]
# What method do you use to remove 20 from s = {10, 20, 30}?

# %%
s = {10, 20, 30}

# %%
s.remove(20)

# %%
s
# Out:
# {10, 30}

# %% [markdown]
# ### 4.Union

# %% [raw]
# If s1 = {1, 2} and s2 = {2, 3}, what is s1.union(s2)?

# %%
s1 = {1, 2}

# %%
s2 = {2, 3}

# %%
s1.union(s2)
# Out:
# {1, 2, 3}

# %% [markdown]
# ### 5.Intersection

# %% [raw]
#  Using the same sets above, what is s1.intersection(s2)?

# %%
s1
# Out:
# {1, 2}

# %%
s2
# Out:
# {2, 3}

# %%
s1.intersection(s2)
# Out:
# {2}

# %% [markdown]
# # Dictionaries

# %% [markdown]
# ### 1.Value Retrieval

# %% [raw]
# Given d = {'name': 'Sham', 'age': 20}, how do you get the age?

# %%
d =  {'name': 'Sham', 'age': 20}

# %%
d['age']
# Out:
# 20

# %% [markdown]
# ### 2.Adding Data

# %% [raw]
# How do you add a new key 'city' with value 'Mumbai' to dictionary d?

# %%
d
# Out:
# {'name': 'Sham', 'age': 20}

# %%
d['city'] = 'Mumbai'

# %%
d
# Out:
# {'name': 'Sham', 'age': 20, 'city': 'Mumbai'}

# %% [markdown]
# ### 3.Updating

# %% [raw]
# How do you change the 'age' in d from 20 to 21?

# %%
d['age'] = 21

# %%
d
# Out:
# {'name': 'Sham', 'age': 21, 'city': 'Mumbai'}

# %% [markdown]
# ### 4.Keys & Values

# %% [raw]
# What command returns all the keys present in a dictionary?

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %% [markdown]
# ### 5.Pop Method

# %% [raw]
# What happens to dictionary d if you run d.pop('name')?

# %%
d.pop('name')
# Out:
# 'Sham'

# %%
# if we use these pop and name them it will give the key name and its value is remove from dictionary

# %%
d
# Out:
# {'age': 21, 'city': 'Mumbai'}

# %% [markdown]
# # Mixed and Advanced Challenges

# %% [markdown]
# ### 1.Conversion

# %% [raw]
# How do you convert a list [1, 2, 2] into a set to remove duplicates, and then back into a list?

# %%
l = [1, 2, 2]

# %%
l = set(l)

# %%
set(l)
# Out:
# {1, 2}

# %%
list(set(l))
# Out:
# [1, 2]

# %% [markdown]
# ### 2.Nested Dictionary

# %% [raw]
# Access 'Maths' score from results = {'student': 'Om', 'scores': {'Maths': 90, 'Science': 85}}.

# %%
results = {'student': 'Om', 'scores': {'Maths': 90, 'Science': 85}}

# %%
results['scores']['Maths']
# Out:
# 90

# %% [markdown]
# ### 3.Tuple length

# %% [raw]
# How do you find how many elements are in t = (1, 2, 3, 4)?

# %%
t = (1, 2, 3, 4)

# %%
len(t)
# Out:
# 4

# %% [markdown]
# ### 4.Set Membership

# %% [raw]
# How do you check if 10 exists in set s?

# %%
s = {10,20,30}

# %%
10 in s
# Out:
# True

# %% [markdown]
# ### 5.Dictionary from list

# %% [raw]
# Can you create a dictionary where keys are numbers 1, 2 and values are their squares 1, 4?

# %%
d = {1 : 1 , 2 : 4 , 3 : 9}

# %%
d
# Out:
# {1: 1, 2: 4, 3: 9}

# %% [markdown]
# ### 5.Dictionary to Dataframe

# %% [raw]
# Based on the notebook, what library is used to turn a dictionary into a table format (DataFrame)?

# %%
# pandas(pd) is used to turn a dictionary into a table format
