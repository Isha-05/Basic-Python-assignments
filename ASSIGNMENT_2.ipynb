# %% [markdown]
# ASSIGNMENT 2

# %% [markdown]
# Data Structures - List, Tuple, Set, and Dictionary

# %% [markdown]
# 1.Working with lists

# %% [raw]
# a) Create a list of integers and:
#     1) Append a new number.
#     2) Insert a number at a specific index.
#     3) Remove duplicates and print the final list.

# %%
l = [1,2,2,3,4,4,5]

# %%
l.append('hello')

# %%
l
# Out:
# [1, 2, 2, 3, 4, 4, 5, 'hello']

# %%
l.insert(2,500)

# %%
l
# Out:
# [1, 2, 500, 2, 3, 4, 4, 5, 'hello']

# %%
o = [1,2,3,3,4,4]

# %%
o.remove(3)

# %%
o
# Out:
# [1, 2, 3, 4, 4]

# %%
o.remove(4)

# %%
o
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# 2. Tuple Manipulation

# %% [raw]
# a)Define a tuple of 5 colors.

# %%
t = ( 'red','yellow','green','orange','blue' )

# %%
t
# Out:
# ('red', 'yellow', 'green', 'orange', 'blue')

# %% [raw]
# b)Try to add a new color to the tuple (observe and explain why it fails).

# %%
t
# Out:
# ('red', 'yellow', 'green', 'orange', 'blue')

# %%
t(2) = 'pink'
# Out:
#   Cell In[14], line 1
#     t(2) = 'pink'
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
# here in tuple we cannot add a new color to it because it is immutable but it can add the color if we convert it first into list then into tuple

# %% [raw]
# c)Convert the tuple to a list, add the color, and convert it back to a tuple.

# %%
t
# Out:
# ('red', 'yellow', 'green', 'orange', 'blue')

# %%
t = list(t)

# %%
t
# Out:
# ['red', 'yellow', 'green', 'orange', 'blue']

# %%
t[2] = 'pink'

# %%
t
# Out:
# ['red', 'yellow', 'pink', 'orange', 'blue']

# %% [markdown]
# 3. Set Operation

# %% [raw]
# a) Create two sets of random numbers.

# %%
s1 = {1,2,3,4,5}

# %%
s2 = {4,5,6,7,8}

# %% [raw]
# b) Find and print their union, intersection, and difference.

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s2
# Out:
# {4, 5, 6, 7, 8}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1.intersection(s2)
# Out:
# {4, 5}

# %%
s1.difference(s2)
# Out:
# {1, 2, 3}

# %%
s2.difference(s1)
# Out:
# {6, 7, 8}

# %% [raw]
# c)Remove one element from the first set and add a new element.

# %%
s1 = {1,2,3,7,8}

# %%
s1.remove(1)

# %%
s1
# Out:
# {2, 3, 7, 8}

# %%
s1.add(10)

# %%
s1
# Out:
# {2, 3, 7, 8, 10}

# %% [markdown]
# 4. Dictionary Practice

# %% [raw]
# a) Define a dictionary for a library system with book titles as keys and available
# copies as values.

# %%
a = { 'Python':'10' ,'Java':'9','C':'8'}

# %%
a
# Out:
# {'Python': '10', 'Java': '9', 'C': '8'}

# %% [raw]
# b) Update the count of a specific book after it is borrowed.

# %%
a
# Out:
# {'Python': '10', 'Java': '9', 'C': '8'}

# %%
a['Python']= '7'

# %%
a
# Out:
# {'Python': '7', 'Java': '9', 'C': '8'}

# %% [raw]
# c) Add a new book to the dictionary and print the updated dictionary.

# %%
a = {'Python':'7','Java':'9','C':'8','Html':'6'}

# %%
a
# Out:
# {'Python': '7', 'Java': '9', 'C': '8', 'Html': '6'}
